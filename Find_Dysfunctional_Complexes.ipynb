# %%
# %%capture
# %run /Users/amandaoliphant/Documents/GitHub/OvarianProspective/Protein_Complexes/Analysis_Functions.ipynb

# %%
ov_results = find_differential_expression()
# Out:
# A1BG: 3.782081593622409e-15 (tumor lower)
# A2M: 2.9703665148364597e-13 (tumor lower)
# AAAS: 4.326233902031055e-11 (normal lower)
# AASS: 2.847735635925295e-08 (tumor lower)
# ABCA10: 4.0819786592224806e-08 (tumor lower)
# ABCA8: 1.922985765059266e-27 (tumor lower)
# ABCA9: 1.3876734563019347e-12 (tumor lower)
# ABHD11: 1.2001866849465728e-06 (normal lower)
# ABHD5: 1.259946873379246e-06 (tumor lower)
# ABI3BP: 9.297063035730211e-23 (tumor lower)
# ABL1: 2.283920525883028e-08 (tumor lower)
# ABRACL: 6.349688422499847e-08 (normal lower)
# ACBD3: 8.375018118790832e-09 (normal lower)
# ACE: 2.2203140150759184e-10 (tumor lower)
# ACIN1: 2.5200971817553174e-13 (normal lower)
# ACIN1: 2.5200971817553174e-13 (normal lower)
# ACOT1: 1.1999817014787065e-10 (tumor lower)
# ACOT2: 4.015548638454741e-11 (tumor lower)
# ACSL1: 3.4379091906214086e-08 (tumor lower)
# ACSL1: 3.4379091906214086e-08 (tumor lower)
# ACSL5: 1.7304556047166325e-07 (tumor lower)
# ...

# %%
en_results = find_differential_expression(cancer_type = 'en')

# %%
colon_results = find_differential_expression(cancer_type = 'colon')
