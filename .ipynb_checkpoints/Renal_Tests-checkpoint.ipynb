# %%
import cptac
import cptac.algorithms as al

# %%
renal = cptac.RenalCcrcc()

# %%
test_genes = list(al.get_frequently_mutated(renal, 0.1)['Gene'])
test_genes
# Out:
# ['BAP1', 'KDM5C', 'PBRM1', 'SETD2', 'TTN', 'VHL']

# %%
renal.get_clinical()
# Out:
#            Patient_ID Sample_Tumor_Normal tumor/normal  gender   age  \
# Sample_ID
# S001        C3L-00004               Tumor           TN    Male    72
# S002        C3L-00010               Tumor           TN    Male    30
# S003        C3L-00011               Tumor           TN  Female    63
# S004        C3L-00026               Tumor           TN  Female    65
# S005        C3L-00079               Tumor           TN    Male    49
# S006        C3L-00088               Tumor           TN    Male    72
# S007        C3L-00096               Tumor           TN    Male    52
# S008        C3L-00097               Tumor           TN    Male    59
# S009        C3L-00103               Tumor           TN    Male    56
# S010        C3L-00183               Tumor           TN  Female    33
# S011        C3L-00359               Tumor            T  Female    73
# S012        C3L-00360               Tumor           TN    Male    72
# ...
