# %%
import cptac
# Out:
# /anaconda3/envs/ptmresearch/lib/python3.7/site-packages/requests/__init__.py:91: RequestsDependencyWarning: urllib3 (1.25.3) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
cptac.download(dataset='renalccrcc', version='latest')
# Out:
# All files already downloaded and correct.
# True

# %%
renal = cptac.RenalCcrcc()

# %%
renal.get_proteomics()
# Out:
#                A1BG      A1CF       A2M    A4GALT      AAAS      AACS  \
# Sample_ID
# S001      -0.304302  0.641447 -0.000025       NaN  0.207831 -0.364128
# S002       1.195915  0.194620  1.360294       NaN  0.126956 -0.572843
# S003      -0.286155 -0.780455 -0.101089       NaN  0.292629  0.035812
# S004       0.135730  0.404286  0.261384       NaN  0.155568  0.336311
# S005      -0.123959 -0.677773 -0.362547       NaN  0.187605 -0.320026
# S006       0.427542  0.310249  1.308011       NaN  0.121887 -0.065935
# S007      -0.242107 -0.128732 -0.256201       NaN  0.240502 -0.111920
# S008       0.506469 -0.513243 -0.495248       NaN  0.135256 -0.221287
# S009       0.720836 -1.135859  0.488708       NaN  0.204237 -0.269864
# S010       0.082946 -0.128068  0.155540       NaN  0.332086 -0.065765
# S011       0.289679 -0.872500  0.143911       NaN  0.097095  0.034773
# S012       0.493943 -0.409002  0.135081       NaN  0.025521  0.180353
# ...
