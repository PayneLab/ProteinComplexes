# %% [markdown]
# # Explore Changes in Expression in Protein Complexes
# This notebook focuses on looking at the percentage of proteins in each complex that show increased/decreased/no change in expression in tumor samples vs normal for each of the cancers included in CPTAC

# %%
# %run /Users/amandaoliphant/Documents/GitHub/ProteinComplexes/Analysis_Functions.ipynb
# Out:
# All files already downloaded and correct.
# All files already downloaded and correct.
# All files already downloaded and correct.
# All files already downloaded and correct.

# %%
# %run /Users/amandaoliphant/Documents/GitHub/ProteinComplexes/Plotting_Functions.ipynb

# %% [markdown]
# ### This notebook was written using a specific version of CPTAC

# %%
cptac.version()
# Out:
# '0.5.2'

# %% [markdown]
# ### Perform a bonferroni correction on the p-value cutoff to account for testing thousands of proteins

# %%
all_proteins = list(set(sum(subunitNames.values(), [])))
adjusted_alpha = 0.05 / len(all_proteins)
print(adjusted_alpha)
# Out:
# 1.3694878115584772e-05

# %% [markdown]
# ## Colon Cancer

# %%
colon_results = ttest_all_complexes(alpha = adjusted_alpha, cancer_type = 'colon')
colon_results
# Out:
#                                            complex_name total_protein_num  \
# 0                                    BCL6-HDAC4 complex                 2
# 1                                    BCL6-HDAC5 complex                 2
# 2                                    BCL6-HDAC7 complex                 2
# 3                 Multisubunit ACTR coactivator complex                 4
# 4                                   Condensin I complex                 5
# 5     BLOC-3 (biogenesis of lysosome-related organel...                 2
# 6     BLOC-2 (biogenesis of lysosome-related organel...                 3
# 7                                    MUS81-CDS1 complex                 2
# 8                                          NCOR complex                 6
# 9     BLOC-1 (biogenesis of lysosome-related organel...                 8
# 10                               Arp2/3 protein complex                 7
# 11                                    PA28gamma complex                 1
# ...

# %%
make_histogram(colon_results, size_cutoffs = [5, 10, 20], norm = True, show_complex = '26S proteasome')

# %% [markdown]
# ## Endometrial Cancer

# %%
en_results = ttest_all_complexes(alpha = adjusted_alpha, cancer_type = 'en')
en_results
# Out:
#                                            complex_name total_protein_num  \
# 0                                    BCL6-HDAC4 complex                 2
# 1                                    BCL6-HDAC5 complex                 2
# 2                                    BCL6-HDAC7 complex                 2
# 3                 Multisubunit ACTR coactivator complex                 4
# 4                                   Condensin I complex                 5
# 5     BLOC-3 (biogenesis of lysosome-related organel...                 2
# 6     BLOC-2 (biogenesis of lysosome-related organel...                 3
# 7                                    MUS81-CDS1 complex                 2
# 8                                          NCOR complex                 6
# 9     BLOC-1 (biogenesis of lysosome-related organel...                 8
# 10                               Arp2/3 protein complex                 7
# 11                                    PA28gamma complex                 1
# ...

# %%
make_histogram(en_results, size_cutoffs = [5, 20], norm = True, show_complex = 'Condensin I complex')

# %% [markdown]
# ## Renal Cancer

# %%
renal_results = ttest_all_complexes(alpha = adjusted_alpha, cancer_type = 'renal')
renal_results
# Out:
#                                            complex_name total_protein_num  \
# 0                                    BCL6-HDAC4 complex                 2
# 1                                    BCL6-HDAC5 complex                 2
# 2                                    BCL6-HDAC7 complex                 2
# 3                 Multisubunit ACTR coactivator complex                 4
# 4                                   Condensin I complex                 5
# 5     BLOC-3 (biogenesis of lysosome-related organel...                 2
# 6     BLOC-2 (biogenesis of lysosome-related organel...                 3
# 7                                    MUS81-CDS1 complex                 2
# 8                                          NCOR complex                 6
# 9     BLOC-1 (biogenesis of lysosome-related organel...                 8
# 10                               Arp2/3 protein complex                 7
# 11                                    PA28gamma complex                 1
# ...

# %%
make_histogram(renal_results, size_cutoffs = [20], norm = True, show_complex = 'Condensin I complex')

# %%
renal_results.loc[colon_results['complex_name'].str.contains('proteasome')]
# Out:
#                       complex_name total_protein_num num_increased_tumor  \
# 78                  26S proteasome                22                  18
# 82                  20S proteasome                14                  10
# 83             PA28-20S proteasome                16                  12
# 85        PA28gamma-20S proteasome                15                  10
# 1406  Ubiquilin-proteasome complex                 6                   4
#
#      num_decreased_tumor no_proteomics_data percent_increased  \
# 78                     3                  0           81.8182
# 82                     3                  0           71.4286
# 83                     3                  0                75
# 85                     4                  0           66.6667
# 1406                   0                  0           66.6667
#
#      percent_decreased
# 78             13.6364
# 82             21.4286
# 83               18.75
# 85             26.6667
# 1406                 0

# %% [markdown]
# ## Ovarian Cancer

# %%
ov_results = ttest_all_complexes(alpha = adjusted_alpha, cancer_type = 'ov')
ov_results
# Out:
#                                            complex_name total_protein_num  \
# 0                                    BCL6-HDAC4 complex                 2
# 1                                    BCL6-HDAC5 complex                 2
# 2                                    BCL6-HDAC7 complex                 2
# 3                 Multisubunit ACTR coactivator complex                 4
# 4                                   Condensin I complex                 5
# 5     BLOC-3 (biogenesis of lysosome-related organel...                 2
# 6     BLOC-2 (biogenesis of lysosome-related organel...                 3
# 7                                    MUS81-CDS1 complex                 2
# 8                                          NCOR complex                 6
# 9     BLOC-1 (biogenesis of lysosome-related organel...                 8
# 10                               Arp2/3 protein complex                 7
# 11                                    PA28gamma complex                 1
# ...

# %%
make_histogram(ov_results, size_cutoffs = [20], norm = True, show_complex = 'Condensin I complex')

# %%
proteasome_proteins = subunitNames['PA700 complex'] + subunitNames['26S proteasome'] + subunitNames['20S proteasome'] + subunitNames['PA28-20S proteasome'] + subunitNames['PA700-20S-PA28 complex'] + subunitNames['PA28gamma-20S proteasome']
proteasome_proteins = list(set(proteasome_proteins))
sub_20s = []
sub_19s = []
pa28 = []
for protein in proteasome_proteins:
    if 'PSMA' in protein or 'PSMB' in protein: sub_20s.append(protein)
    elif 'PSMC' in protein or 'PSMD' in protein: sub_19s.append(protein)
    else: pa28.append(protein)

# %%
sub_20s.sort()
pancancer_plot_proteins(protein_list = sub_20s, show_ttest = True)
# Out:
# Unique Protein List
#
# Colon cancer:
# PSMA1: 1.289374891174728e-13
# PSMA2: 8.123122524198827e-06
# PSMA3: 3.042226326082461e-08
# PSMA4: 2.3410017942941278e-07
# PSMA5: 4.906971391818451e-09
# PSMA6: 3.3553315400473855e-06
# PSMA7: 2.4708591866353053e-19
# PSMB1: 0.010246340791591984
# PSMB2: 0.6278613034572595
# PSMB3: 0.10470841775468703
# PSMB4: 0.006332211994968573
# PSMB5: 2.975078326021348e-07
# PSMB6: 1.755575810797984e-12
# PSMB7: 0.9277811234481886
#
#
# Endometrial cancer:
# PSMA1: 1.2897451680282952e-08
# PSMA2: 8.525865980367157e-08
# PSMA3: 8.55238675940265e-10
# PSMA4: 9.274441822693712e-12
# PSMA5: 0.002638564402051185
# PSMA6: 3.283027720904489e-10
# PSMA7: 6.634900096501084e-08
# PSMB1: 2.2604489175276164e-09
# PSMB2: 0.006388675112741937
# PSMB3: 1.9864565569901707e-07
# PSMB4: 1.4033852258652318e-07
# PSMB5: 0.3651793191135808
# PSMB6: 0.00039786972287493333
# PSMB7: 0.0007591555856441795
#
#
# Renal cancer:
# PSMA1: 3.3693262199345677e-41
# ...
