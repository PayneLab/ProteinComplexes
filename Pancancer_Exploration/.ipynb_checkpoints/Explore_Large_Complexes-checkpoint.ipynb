# %%
# %run /Users/amandaoliphant/Documents/GitHub/ProteinComplexes/Analysis_Functions.ipynb
# Out:
# All files already downloaded and correct.
# All files already downloaded and correct.
# All files already downloaded and correct.
# All files already downloaded and correct.

# %%
# %run /Users/amandaoliphant/Documents/GitHub/ProteinComplexes/Plotting_Functions.ipynb

# %% [markdown]
# ### This notebook was written using a specific version of CPTAC

# %%
cptac.version()
# Out:
# '0.5.2'

# %% [markdown]
# ### Get a list of large complexes (>= 20 proteins)

# %%
large_complexes = []
for key, val in subunitNames.items():
    if len(val) >=20:
        large_complexes.append(key)
large_complexes
# Out:
# ['PA700 complex',
#  'RNA polymerase II holoenzyme complex',
#  'Respiratory chain complex I (holoenzyme), mitochondrial',
#  '26S proteasome',
#  'PA700-20S-PA28 complex',
#  'Mediator complex',
#  '40S ribosomal subunit, cytoplasmic',
#  'Ribosome, cytoplasmic',
#  '60S ribosomal subunit, cytoplasmic',
#  '28S ribosomal subunit, mitochondrial',
#  '55S ribosome, mitochondrial',
#  '39S ribosomal subunit, mitochondrial',
#  'Spliceosome',
#  '18S U11/U12 snRNP',
#  'CEN complex',
#  'C complex spliceosome',
#  'CDC5L complex',
#  'ALL-1 supercomplex',
#  'Large Drosha complex',
#  '17S U2 snRNP',
#  'BRCA1-RNA polymerase II complex',
#  'Nop56p-associated pre-rRNA complex',
#  'TNF-alpha/NF-kappa B signaling complex 5',
#  'TRBP containing complex (DICER, RPL7A, EIF6, MOV10 and subunits of the 60S ribosomal particle)',
#  'MLL1-WDR5 complex',
#  'Emerin complex 32',
#  'Emerin complex 52']

# %% [markdown]
# ## Specific Complex Analysis

# %%
for complex_name in large_complexes:
    print(complex_name + '\n')
    analysis = pancancer_analyze_complex(complex_name, include_borderline = True)
    print('\n')
# Out:
# PA700 complex
#
# Borderline changes included; alpha set to 0.05
#
# Increased in all cancers:
# ['PSMD12', 'PSMD14', 'PSMD3', 'PSMC3', 'PSMC2', 'PSMD8', 'PSMD7', 'PSMC1', 'PSMD6', 'PSMD1', 'PSMD13']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['PSMD11', 'PSMD9', 'PSMD10', 'PSMC4', 'PSMD4', 'PSMC5', 'PSMC6', 'PSMD2', 'PSMD5']
# Missing proteomics data in at least one cancer:
# []
#
#
# RNA polymerase II holoenzyme complex
#
# Borderline changes included; alpha set to 0.05
#
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# GTF2H2 did not match any columns in proteomics dataframe. GTF2H2_proteomics column inserted, but filled with NaN.
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# GTF2H2 did not match any columns in proteomics dataframe. GTF2H2_proteomics column inserted, but filled with NaN.
# POLR2A did not match any columns in proteomics dataframe. POLR2A_proteomics column inserted, but filled with NaN.
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['GTF2E2']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['POLR2D', 'GTF2F2', 'ERCC2', 'POLR2C', 'POLR2E', 'ERCC3', 'TBP', 'GTF2E1', 'POLR2B', 'GTF2H1', 'GTF2F1', 'POLR2I', 'POLR2H', 'POLR2K', 'POLR2F', 'POLR2G', 'POLR2L', 'GTF2B', 'GTF2H3', 'GTF2H4']
# Missing proteomics data in at least one cancer:
# ['POLR2A', 'POLR2J', 'GTF2H2']
#
#
# Respiratory chain complex I (holoenzyme), mitochondrial
#
# Borderline changes included; alpha set to 0.05
#
# MT-ND1 did not match any columns in proteomics dataframe. MT-ND1_proteomics column inserted, but filled with NaN.
# MT-ND2 did not match any columns in proteomics dataframe. MT-ND2_proteomics column inserted, but filled with NaN.
# MT-ND3 did not match any columns in proteomics dataframe. MT-ND3_proteomics column inserted, but filled with NaN.
# MT-ND4L did not match any columns in proteomics dataframe. MT-ND4L_proteomics column inserted, but filled with NaN.
# MT-ND5 did not match any columns in proteomics dataframe. MT-ND5_proteomics column inserted, but filled with NaN.
# MT-ND6 did not match any columns in proteomics dataframe. MT-ND6_proteomics column inserted, but filled with NaN.
# MT-ND4L did not match any columns in proteomics dataframe. MT-ND4L_proteomics column inserted, but filled with NaN.
# NDUFA1 did not match any columns in proteomics dataframe. NDUFA1_proteomics column inserted, but filled with NaN.
# NDUFC1 did not match any columns in proteomics dataframe. NDUFC1_proteomics column inserted, but filled with NaN.
# MT-ND3 did not match any columns in proteomics dataframe. MT-ND3_proteomics column inserted, but filled with NaN.
# MT-ND4L did not match any columns in proteomics dataframe. MT-ND4L_proteomics column inserted, but filled with NaN.
# MT-ND6 did not match any columns in proteomics dataframe. MT-ND6_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# []
# Decreased in all cancers:
# ['NDUFV3']
# No change in all cancers:
# []
# Mixed results:
# ['NDUFS8', 'NDUFA4', 'NDUFAB1', 'NDUFS4', 'NDUFB5', 'NDUFB3', 'NDUFA2', 'NDUFS5', 'NDUFS7', 'NDUFS2', 'NDUFS6', 'NDUFB1', 'NDUFS3', 'NDUFB6', 'NDUFA3', 'NDUFB4', 'NDUFB8', 'NDUFB2', 'NDUFA7', 'NDUFC2', 'NDUFA10', 'NDUFB10', 'NDUFB7', 'NDUFV2', 'NDUFS1', 'NDUFV1', 'NDUFA8', 'NDUFA6', 'NDUFA5', 'NDUFA9', 'NDUFA11', 'NDUFB11', 'NDUFA13', 'NDUFA12', 'NDUFB9']
# Missing proteomics data in at least one cancer:
# ['NDUFA1', 'NDUFC1', 'MT-ND1', 'MT-ND2', 'MT-ND3', 'MT-ND4L', 'MT-ND5', 'MT-ND6']
#
#
# 26S proteasome
#
# Borderline changes included; alpha set to 0.05
#
# Increased in all cancers:
# ['PSMA7', 'PSMC3', 'PSMA1', 'PSMA4', 'PSMA5', 'PSMC2', 'PSMA6', 'PSMC1', 'PSMD13']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['PSMB1', 'PSMA2', 'PSMA3', 'PSMB4', 'PSMB6', 'PSMB5', 'PSMC4', 'PSMB3', 'PSMB2', 'PSMD4', 'PSMC5', 'PSMC6', 'PSMB7']
# Missing proteomics data in at least one cancer:
# []
#
#
# PA700-20S-PA28 complex
#
# Borderline changes included; alpha set to 0.05
#
# Increased in all cancers:
# ['PSMD12', 'PSMD14', 'PSMA7', 'PSMD3', 'PSMC3', 'PSMA1', 'PSMA4', 'PSMA5', 'PSMC2', 'PSMD8', 'PSMD7', 'PSMA6', 'PSMC1', 'PSME1', 'PSMD6', 'PSMD1', 'PSME2', 'PSMD13']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['PSMD11', 'PSMD9', 'PSMD10', 'PSMB1', 'PSMA2', 'PSMA3', 'PSMB4', 'PSMB6', 'PSMB5', 'PSMC4', 'PSMB3', 'PSMB2', 'PSMD4', 'PSMC5', 'PSMC6', 'PSMD2', 'PSMD5', 'PSMB7']
# Missing proteomics data in at least one cancer:
# []
#
#
# Mediator complex
#
# Borderline changes included; alpha set to 0.05
#
# MED7 did not match any columns in proteomics dataframe. MED7_proteomics column inserted, but filled with NaN.
# MED26 did not match any columns in proteomics dataframe. MED26_proteomics column inserted, but filled with NaN.
# CCNC did not match any columns in proteomics dataframe. CCNC_proteomics column inserted, but filled with NaN.
# MED13L did not match any columns in proteomics dataframe. MED13L_proteomics column inserted, but filled with NaN.
# MED25 did not match any columns in proteomics dataframe. MED25_proteomics column inserted, but filled with NaN.
# MED12 did not match any columns in proteomics dataframe. MED12_proteomics column inserted, but filled with NaN.
# MED13 did not match any columns in proteomics dataframe. MED13_proteomics column inserted, but filled with NaN.
# MED31 did not match any columns in proteomics dataframe. MED31_proteomics column inserted, but filled with NaN.
# CCNC did not match any columns in proteomics dataframe. CCNC_proteomics column inserted, but filled with NaN.
# MED31 did not match any columns in proteomics dataframe. MED31_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['MED24', 'MED23', 'MED16']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['MED19', 'MED14', 'MED6', 'CDK8', 'MED21', 'MED22', 'MED1', 'MED27', 'MED8', 'MED30', 'MED15', 'MED10', 'MED18', 'CDK19', 'MED28', 'MED20', 'MED4', 'MED17', 'MED9', 'MED29', 'MED11']
# Missing proteomics data in at least one cancer:
# ['MED7', 'MED26', 'CCNC', 'MED13L', 'MED25', 'MED12', 'MED13', 'MED31']
#
#
# 40S ribosomal subunit, cytoplasmic
#
# Borderline changes included; alpha set to 0.05
#
# RPS4Y1 did not match any columns in proteomics dataframe. RPS4Y1_proteomics column inserted, but filled with NaN.
# RPS4Y1 did not match any columns in proteomics dataframe. RPS4Y1_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['RPS17', 'RPSA', 'RPS12', 'RPS19', 'RPS27', 'RPS9', 'RPS5', 'RPS10', 'RPS3A', 'RPS7', 'RPS8', 'RPS23', 'RPS18', 'RPS13', 'RPS11', 'RPS4X', 'RPS6', 'RPS15', 'RPS24', 'RPS25', 'RPS28', 'FAU', 'RPS21']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['RPS2', 'RPS3', 'RPS20', 'RPS15A', 'RPS16', 'RPS14', 'RPS29', 'RPS26', 'RPS27A']
# Missing proteomics data in at least one cancer:
# ['RPS4Y1']
#
#
# Ribosome, cytoplasmic
#
# Borderline changes included; alpha set to 0.05
#
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# RPL41 did not match any columns in proteomics dataframe. RPL41_proteomics column inserted, but filled with NaN.
# RPS4Y1 did not match any columns in proteomics dataframe. RPS4Y1_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# RPL41 did not match any columns in proteomics dataframe. RPL41_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# RPL41 did not match any columns in proteomics dataframe. RPL41_proteomics column inserted, but filled with NaN.
# UBA52 did not match any columns in proteomics dataframe. UBA52_proteomics column inserted, but filled with NaN.
# RPL36A did not match any columns in proteomics dataframe. RPL36A_proteomics column inserted, but filled with NaN.
# RPS4Y1 did not match any columns in proteomics dataframe. RPS4Y1_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# RPL41 did not match any columns in proteomics dataframe. RPL41_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# 
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# C19orf43 did not match any columns in proteomics dataframe. C19orf43_proteomics column inserted, but filled with NaN.
# MAGOH did not match any columns in proteomics dataframe. MAGOH_proteomics column inserted, but filled with NaN.
# FNBP3 did not match any columns in proteomics dataframe. FNBP3_proteomics column inserted, but filled with NaN.
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# C19orf43 did not match any columns in proteomics dataframe. C19orf43_proteomics column inserted, but filled with NaN.
# ISY1 did not match any columns in proteomics dataframe. ISY1_proteomics column inserted, but filled with NaN.
# MTREX did not match any columns in proteomics dataframe. MTREX_proteomics column inserted, but filled with NaN.
# FNBP3 did not match any columns in proteomics dataframe. FNBP3_proteomics column inserted, but filled with NaN.
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# C19orf43 did not match any columns in proteomics dataframe. C19orf43_proteomics column inserted, but filled with NaN.
# ISY1 did not match any columns in proteomics dataframe. ISY1_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['IGF2BP3', 'DDX3X', 'PPM1G', 'DHX15', 'PRPF4', 'PRPF3', 'SNRNP200', 'SLU7', 'SNRPA1', 'PABPC1', 'U2AF2', 'EIF4A3', 'NCBP2', 'SNRPG', 'SNRPD2', 'SNRPD3', 'THOC5', 'EFTUD2', 'SF3B3', 'SF1', 'PRPF8', 'DDX46', 'RBM17', 'CWC15', 'TFIP11', 'PUF60', 'DDX41', 'PRPF19', 'SRRM2', 'SF3B6']
# Decreased in all cancers:
# []
# No change in all cancers:
# ['PPIL3']
# Mixed results:
# ['TCERG1', 'U2SURP', 'SART1', 'PPIH', 'PLRG1', 'ZNF207', 'HTATSF1', 'NUDT21', 'DHX16', 'AQR', 'CDC40', 'PRPF40A', 'SF3B1', 'BCAS2', 'DNAJC8', 'SMNDC1', 'PRPF6', 'LUC7L3', 'CD2BP2', 'SYF2', 'SNRPB2', 'SNRNP70', 'SNRPA', 'SNRPC', 'DDX5', 'BUD31', 'RBM25', 'MFAP1', 'SNU13', 'SNRPE', 'SNRPF', 'LSM3', 'LSM6', 'SNRPD1', 'TRA2B', 'TXNL4A', 'SRSF3', 'U2AF1', 'SRSF2', 'SRSF11', 'SRSF1', 'SRSF4', 'DHX9', 'NCBP1', 'SF3A3', 'IK', 'SRSF9', 'SRSF5', 'SRSF6', 'PPIL2', 'SF3B2', 'PRPF4B', 'SNW1', 'DDX39B', 'CIRBP', 'RBM39', 'DHX8', 'WTAP', 'RNPS1', 'SF3B4', 'SF3A2', 'SF3A1', 'SRSF7', 'CPSF6', 'SMU1', 'USP39', 'THOC7', 'ALYREF', 'THOC6', 'SRRM1', 'THOC2', 'CACTIN', 'SNRNP27', 'PRPF31', 'CTNNBL1', 'DHX38', 'DDX17', 'PPWD1', 'SNRNP40', 'THOC1', 'THOC3', 'RBM15', 'CDC5L', 'PRPF18', 'BUD13', 'DDX23', 'SRRT', 'CRNKL1', 'MOV10', 'CWC22', 'XAB2', 'RBM22', 'CDK12', 'LSM7', 'ACIN1', 'PPIE', 'WBP11', 'LSM2', 'PPIL1', 'LSM4', 'PAXBP1', 'RBM8A', 'CFAP20']
# Missing proteomics data in at least one cancer:
# ['SNRPB', 'MTREX', 'MAGOH', 'FNBP3', 'KIAA1429', 'DGCR14', 'SPEN', 'C19orf43', 'ISY1']
#
#
# 18S U11/U12 snRNP
#
# Borderline changes included; alpha set to 0.05
#
# SNRPB did not match any columns in proteomics dataframe. SNRPB_proteomics column inserted, but filled with NaN.
# ZRSR2 did not match any columns in proteomics dataframe. ZRSR2_proteomics column inserted, but filled with NaN.
# SNRNP35 did not match any columns in proteomics dataframe. SNRNP35_proteomics column inserted, but filled with NaN.
# SNRNP48 did not match any columns in proteomics dataframe. SNRNP48_proteomics column inserted, but filled with NaN.
# PDCD7 did not match any columns in proteomics dataframe. PDCD7_proteomics column inserted, but filled with NaN.
# RNPC3 did not match any columns in proteomics dataframe. RNPC3_proteomics column inserted, but filled with NaN.
# SNRNP25 did not match any columns in proteomics dataframe. SNRNP25_proteomics column inserted, but filled with NaN.
# ZMAT5 did not match any columns in proteomics dataframe. ZMAT5_proteomics column inserted, but filled with NaN.
# SNRNP25 did not match any columns in proteomics dataframe. SNRNP25_proteomics column inserted, but filled with NaN.
# SNRNP35 did not match any columns in proteomics dataframe. SNRNP35_proteomics column inserted, but filled with NaN.
# SNRNP25 did not match any columns in proteomics dataframe. SNRNP25_proteomics column inserted, but filled with NaN.
# ZMAT5 did not match any columns in proteomics dataframe. ZMAT5_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['DHX15', 'SNRPG', 'SNRPD2', 'SNRPD3', 'YBX1', 'SF3B3', 'PRPF8', 'SF3B6']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['SF3B1', 'SNRPE', 'SNRPF', 'SNRPD1', 'SF3B2', 'SF3B4', 'ZCRB1', 'SF3B5']
# Missing proteomics data in at least one cancer:
# ['SNRPB', 'ZRSR2', 'SNRNP35', 'SNRNP48', 'PDCD7', 'RNPC3', 'SNRNP25', 'ZMAT5']
#
#
# CEN complex
#
# Borderline changes included; alpha set to 0.05
#
# BMI1 did not match any columns in proteomics dataframe. BMI1_proteomics column inserted, but filled with NaN.
# CENPA did not match any columns in proteomics dataframe. CENPA_proteomics column inserted, but filled with NaN.
# PLPPR3 did not match any columns in proteomics dataframe. PLPPR3_proteomics column inserted, but filled with NaN.
# CENPU did not match any columns in proteomics dataframe. CENPU_proteomics column inserted, but filled with NaN.
# CENPL did not match any columns in proteomics dataframe. CENPL_proteomics column inserted, but filled with NaN.
# SHCBP1 did not match any columns in proteomics dataframe. SHCBP1_proteomics column inserted, but filled with NaN.
# CENPI did not match any columns in proteomics dataframe. CENPI_proteomics column inserted, but filled with NaN.
# CENPK did not match any columns in proteomics dataframe. CENPK_proteomics column inserted, but filled with NaN.
# CENPO did not match any columns in proteomics dataframe. CENPO_proteomics column inserted, but filled with NaN.
# CENPH did not match any columns in proteomics dataframe. CENPH_proteomics column inserted, but filled with NaN.
# CENPM did not match any columns in proteomics dataframe. CENPM_proteomics column inserted, but filled with NaN.
# BMI1 did not match any columns in proteomics dataframe. BMI1_proteomics column inserted, but filled with NaN.
# CENPA did not match any columns in proteomics dataframe. CENPA_proteomics column inserted, but filled with NaN.
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# PLPPR3 did not match any columns in proteomics dataframe. PLPPR3_proteomics column inserted, but filled with NaN.
# CENPL did not match any columns in proteomics dataframe. CENPL_proteomics column inserted, but filled with NaN.
# CENPI did not match any columns in proteomics dataframe. CENPI_proteomics column inserted, but filled with NaN.
# CENPO did not match any columns in proteomics dataframe. CENPO_proteomics column inserted, but filled with NaN.
# BMI1 did not match any columns in proteomics dataframe. BMI1_proteomics column inserted, but filled with NaN.
# CENPA did not match any columns in proteomics dataframe. CENPA_proteomics column inserted, but filled with NaN.
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# PLPPR3 did not match any columns in proteomics dataframe. PLPPR3_proteomics column inserted, but filled with NaN.
# CENPI did not match any columns in proteomics dataframe. CENPI_proteomics column inserted, but filled with NaN.
# BMI1 did not match any columns in proteomics dataframe. BMI1_proteomics column inserted, but filled with NaN.
# CENPA did not match any columns in proteomics dataframe. CENPA_proteomics column inserted, but filled with NaN.
# KIAA1429 did not match any columns in proteomics dataframe. KIAA1429_proteomics column inserted, but filled with NaN.
# PLPPR3 did not match any columns in proteomics dataframe. PLPPR3_proteomics column inserted, but filled with NaN.
# CENPO did not match any columns in proteomics dataframe. CENPO_proteomics column inserted, but filled with NaN.
# CENPM did not match any columns in proteomics dataframe. CENPM_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['SMARCA5', 'HSPA5', 'FBL', 'CBX3', 'CUL4A', 'RACGAP1', 'CBX8']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['CENPB', 'HSPA8', 'KIF23', 'CENPC', 'RING1', 'SSRP1', 'WTAP', 'DDB1', 'COBLL1', 'ZC3H13', 'NUP93', 'DHX38', 'ZFP91', 'RSF1', 'RNF2', 'SRRT', 'WDR11', 'SUPT16H']
# Missing proteomics data in at least one cancer:
# ['BMI1', 'CENPA', 'KIAA1429', 'PLPPR3', 'CENPU', 'CENPL', 'SHCBP1', 'CENPI', 'CENPK', 'CENPO', 'CENPH', 'CENPM']
#
#
# C complex spliceosome
#
# Borderline changes included; alpha set to 0.05
#
# SNRPB did not match any columns in proteomics dataframe. SNRPB_proteomics column inserted, but filled with NaN.
# MTREX did not match any columns in proteomics dataframe. MTREX_proteomics column inserted, but filled with NaN.
# MAGOH did not match any columns in proteomics dataframe. MAGOH_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# MAGOH did not match any columns in proteomics dataframe. MAGOH_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# ISY1 did not match any columns in proteomics dataframe. ISY1_proteomics column inserted, but filled with NaN.
# MTREX did not match any columns in proteomics dataframe. MTREX_proteomics column inserted, but filled with NaN.
# DGCR14 did not match any columns in proteomics dataframe. DGCR14_proteomics column inserted, but filled with NaN.
# ISY1 did not match any columns in proteomics dataframe. ISY1_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['SYNCRIP', 'SNRNP200', 'SLU7', 'HNRNPA1', 'SNRPA1', 'PABPC1', 'EIF4A3', 'HNRNPM', 'HNRNPF', 'SNRPG', 'SNRPD2', 'SNRPD3', 'HNRNPU', 'EFTUD2', 'SF3B3', 'PRPF8', 'CWC15', 'TFIP11', 'DDX41', 'RALY', 'PRPF19', 'SRRM2']
# Decreased in all cancers:
# []
# No change in all cancers:
# ['PPIL3', 'DHX35']
# Mixed results:
# ['SART1', 'HNRNPR', 'PLRG1', 'AQR', 'CDC40', 'SF3B1', 'PRPF6', 'SYF2', 'HNRNPC', 'SNRPB2', 'DDX5', 'HNRNPA2B1', 'HNRNPH1', 'RBMX', 'HNRNPA3', 'HNRNPK', 'SNRPE', 'SNRPF', 'LSM3', 'SNRPD1', 'U2AF1', 'SRSF1', 'SF3A3', 'SF3B2', 'PRPF4B', 'SNW1', 'FRG1', 'DHX8', 'SF3A2', 'SF3A1', 'ZCCHC8', 'CWC27', 'ALYREF', 'SRRM1', 'CACTIN', 'DHX38', 'PPWD1', 'SNRNP40', 'CDC5L', 'GPATCH1', 'WDR83', 'DDX23', 'CRNKL1', 'PNN', 'CWC22', 'XAB2', 'RBM22', 'PPIE', 'LSM2', 'PPIL1', 'RBM8A']
# Missing proteomics data in at least one cancer:
# ['SNRPB', 'MTREX', 'MAGOH', 'DGCR14', 'ISY1']
#
#
# CDC5L complex
#
# Borderline changes included; alpha set to 0.05
#
# SFI1 did not match any columns in proteomics dataframe. SFI1_proteomics column inserted, but filled with NaN.
# PPM1D did not match any columns in proteomics dataframe. PPM1D_proteomics column inserted, but filled with NaN.
# TCF4 did not match any columns in proteomics dataframe. TCF4_proteomics column inserted, but filled with NaN.
# SFI1 did not match any columns in proteomics dataframe. SFI1_proteomics column inserted, but filled with NaN.
# PPM1D did not match any columns in proteomics dataframe. PPM1D_proteomics column inserted, but filled with NaN.
# SFI1 did not match any columns in proteomics dataframe. SFI1_proteomics column inserted, but filled with NaN.
# SFI1 did not match any columns in proteomics dataframe. SFI1_proteomics column inserted, but filled with NaN.
# PPM1D did not match any columns in proteomics dataframe. PPM1D_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['SNRPA1', 'TOP2A', 'SNRPD2', 'SNRPD3', 'BZW1', 'CWC15', 'PRPF19']
# Decreased in all cancers:
# []
# No change in all cancers:
# ['SCAF8']
# Mixed results:
# ['PLRG1', 'SF3B1', 'BCAS2', 'SNRPA', 'HSPA8', 'SFPQ', 'RBMX', 'PPP1CA', 'SNRPD1', 'PRKDC', 'SRSF2', 'SRSF1', 'ILF2', 'SF3B2', 'DYNC1H1', 'SF3B4', 'SRRM1', 'GCN1', 'CDC5L']
# Missing proteomics data in at least one cancer:
# ['SFI1', 'PPM1D', 'TCF4']
#
#
# ALL-1 supercomplex
#
# Borderline changes included; alpha set to 0.05
#
# TAF1 did not match any columns in proteomics dataframe. TAF1_proteomics column inserted, but filled with NaN.
# KMT2A did not match any columns in proteomics dataframe. KMT2A_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['SMARCA5', 'KDM1A', 'MTA2', 'RAN', 'RBBP4', 'EFTUD2', 'RBBP7', 'SYMPK']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['SAP18', 'SAP30', 'MBD3', 'TBP', 'TAF6', 'SMARCA2', 'WDR5', 'SMARCB1', 'CHD3', 'HDAC1', 'TAF9', 'SMARCC2', 'HDAC2', 'SMARCC1', 'SIN3A', 'CPSF2']
# Missing proteomics data in at least one cancer:
# ['TAF1', 'KMT2A', 'KDM6B', 'TAF12']
#
#
# Large Drosha complex
#
# Borderline changes included; alpha set to 0.05
#
# DGCR8 did not match any columns in proteomics dataframe. DGCR8_proteomics column inserted, but filled with NaN.
# DROSHA did not match any columns in proteomics dataframe. DROSHA_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['DDX3X', 'DHX15', 'HNRNPM', 'HNRNPU', 'RALY']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['HNRNPDL', 'DDX5', 'HNRNPH1', 'FUS', 'EWSR1', 'ILF2', 'ILF3', 'TARDBP', 'DDX1', 'TAF15', 'DDX17', 'SRPK1', 'HNRNPUL1']
# Missing proteomics data in at least one cancer:
# ['DGCR8', 'DROSHA']
#
#
# 17S U2 snRNP
#
# Borderline changes included; alpha set to 0.05
#
# SNRPB did not match any columns in proteomics dataframe. SNRPB_proteomics column inserted, but filled with NaN.
# HMG20B did not match any columns in proteomics dataframe. HMG20B_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['DHX15', 'SNRPA1', 'U2AF2', 'SNRPG', 'SNRPD2', 'SNRPD3', 'SF3B3', 'DDX46', 'CHERP', 'RBM17', 'PUF60', 'SF3B6']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['U2SURP', 'SF3B1', 'DNAJC8', 'SMNDC1', 'SNRPB2', 'HSPD1', 'SNRPE', 'SNRPF', 'SNRPD1', 'U2AF1', 'SRSF1', 'SF3A3', 'TRAP1', 'SF3B2', 'SF3B4', 'SF3A2', 'SF3A1', 'PHF5A', 'SF3B5']
# Missing proteomics data in at least one cancer:
# ['SNRPB', 'HMG20B']
#
#
# BRCA1-RNA polymerase II complex
#
# Borderline changes included; alpha set to 0.05
#
# BRCA1 did not match any columns in proteomics dataframe. BRCA1_proteomics column inserted, but filled with NaN.
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# GTF2H2 did not match any columns in proteomics dataframe. GTF2H2_proteomics column inserted, but filled with NaN.
# BRCA1 did not match any columns in proteomics dataframe. BRCA1_proteomics column inserted, but filled with NaN.
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# GTF2H2 did not match any columns in proteomics dataframe. GTF2H2_proteomics column inserted, but filled with NaN.
# POLR2A did not match any columns in proteomics dataframe. POLR2A_proteomics column inserted, but filled with NaN.
# BRCA1 did not match any columns in proteomics dataframe. BRCA1_proteomics column inserted, but filled with NaN.
# POLR2J did not match any columns in proteomics dataframe. POLR2J_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['GTF2E2']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['POLR2D', 'GTF2F2', 'ERCC2', 'POLR2C', 'POLR2E', 'ERCC3', 'TBP', 'GTF2E1', 'POLR2B', 'GTF2H1', 'GTF2F1', 'POLR2I', 'POLR2H', 'POLR2K', 'POLR2F', 'POLR2G', 'POLR2L', 'GTF2B', 'MED21', 'GTF2H3', 'GTF2H4']
# Missing proteomics data in at least one cancer:
# ['POLR2A', 'BRCA1', 'POLR2J', 'GTF2H2']
#
#
# Nop56p-associated pre-rRNA complex
#
# Borderline changes included; alpha set to 0.05
#
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# TUBA1A did not match any columns in proteomics dataframe. TUBA1A_proteomics column inserted, but filled with NaN.
# HIST1H2BM did not match any columns in proteomics dataframe. HIST1H2BM_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# TUBA1A did not match any columns in proteomics dataframe. TUBA1A_proteomics column inserted, but filled with NaN.
# HIST1H2BM did not match any columns in proteomics dataframe. HIST1H2BM_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# ACTG2 did not match any columns in proteomics dataframe. ACTG2_proteomics column inserted, but filled with NaN.
# RPL36A did not match any columns in proteomics dataframe. RPL36A_proteomics column inserted, but filled with NaN.
# TUBA1A did not match any columns in proteomics dataframe. TUBA1A_proteomics column inserted, but filled with NaN.
# HIST1H2BM did not match any columns in proteomics dataframe. HIST1H2BM_proteomics column inserted, but filled with NaN.
#  RPL9 did not match any columns in proteomics dataframe.  RPL9_proteomics column inserted, but filled with NaN.
# TUBA1A did not match any columns in proteomics dataframe. TUBA1A_proteomics column inserted, but filled with NaN.
# HIST1H2BM did not match any columns in proteomics dataframe. HIST1H2BM_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['RSL1D1', 'RPLP1', 'RPLP2', 'RPS17', 'HNRNPA1', 'EEF2', 'RPL35A', 'RPL7', 'RPL17', 'FBL', 'RPS12', 'U2AF2', 'RPL13', 'RPL10', 'RPL12', 'RPL22', 'RPL4', 'SRP14', 'RPL3', 'RPL13A', 'RPL27A', 'RPL5', 'RPL21', 'RPL28', 'RPS9', 'RPL14', 'HNRNPM', 'NAP1L1', 'RPS3A', 'RPL26', 'RPL15', 'RPL27', 'RPS7', 'RPS8', 'RPS23', 'RPS18', 'RPS13', 'RPS11', 'RPL7A', 'RPL23A', 'RPS6', 'RPL23', 'RPS15', 'RPS24', 'RPL31', 'RPL10A', 'RPL32', 'RPL11', 'RPL8', 'YBX1', 'RPL24', 'HNRNPU', 'RPL18A', 'RPL18', 'PWP1', 'NOLC1', 'BRIX1', 'MYBBP1A', 'GNL3', 'DDX21', 'RBM28', 'LYAR', 'NOP58']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['NOP56', 'SLC25A5', 'RPLP0', 'NPM1', 'TOP1', 'RPS2', 'HIST1H1D', 'NCL', 'RPL9', 'RPL35', 'RPL29', 'TUFM', 'SNU13', 'RPL37A', 'RPS15A', 'RPS16', 'RPS14', 'RPS29', 'ACTA2', 'RPL30', 'RPL39', 'EEF1A1', 'RPL19', 'U2AF1', 'RPL6', 'DHX9', 'ILF2', 'ILF3', 'TCOF1', 'SCYL2', 'H1FX', 'SRPK1', 'EBNA1BP2', 'TUBB1', 'IGF2BP1', 'LUC7L2', 'RPL36']
# Missing proteomics data in at least one cancer:
# [' RPL9', 'ACTG2', 'RPL36A', 'TUBA1A', 'HIST1H2BM']
#
#
# TNF-alpha/NF-kappa B signaling complex 5
#
# Borderline changes included; alpha set to 0.05
#
# MCC did not match any columns in proteomics dataframe. MCC_proteomics column inserted, but filled with NaN.
# FBXW11 did not match any columns in proteomics dataframe. FBXW11_proteomics column inserted, but filled with NaN.
# CD3EAP did not match any columns in proteomics dataframe. CD3EAP_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['KPNA2']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['IKBKB', 'CHUK', 'POLR1A', 'NFKB1', 'LRPPRC', 'MTIF2', 'POLR2H', 'POLR2L', 'SKP1', 'NFKB2', 'RELA', 'REL', 'IQGAP2', 'CUL1', 'NFKBIB', 'PDCD2', 'POLR1E', 'POLR1B', 'RASAL2', 'POLR1D', 'IKBKG']
# Missing proteomics data in at least one cancer:
# ['CD3EAP', 'MCC', 'FBXW11']
#
#
# TRBP containing complex (DICER, RPL7A, EIF6, MOV10 and subunits of the 60S ribosomal particle)
#
# Borderline changes included; alpha set to 0.05
#
# Increased in all cancers:
# ['RPLP1', 'RPLP2', 'RPL35A', 'RPL7', 'RPL13', 'RPL12', 'RPL21', 'RPL28', 'RPL14', 'RPL15', 'RPL27', 'RPL7A', 'RPL10A', 'RPL32', 'RPL11', 'RPL18A', 'RSL24D1']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['RPL34', 'EIF6', 'RPL37A', 'RPL30', 'RPL19', 'MOV10', 'DICER1', 'RPL36']
# Missing proteomics data in at least one cancer:
# []
#
#
# MLL1-WDR5 complex
#
# Borderline changes included; alpha set to 0.05
#
# E2F6 did not match any columns in proteomics dataframe. E2F6_proteomics column inserted, but filled with NaN.
# TAF1 did not match any columns in proteomics dataframe. TAF1_proteomics column inserted, but filled with NaN.
# KMT2A did not match any columns in proteomics dataframe. KMT2A_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# KANSL1 did not match any columns in proteomics dataframe. KANSL1_proteomics column inserted, but filled with NaN.
# BAP18 did not match any columns in proteomics dataframe. BAP18_proteomics column inserted, but filled with NaN.
# PHF20 did not match any columns in proteomics dataframe. PHF20_proteomics column inserted, but filled with NaN.
# MGAM did not match any columns in proteomics dataframe. MGAM_proteomics column inserted, but filled with NaN.
# E2F6 did not match any columns in proteomics dataframe. E2F6_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# BAP18 did not match any columns in proteomics dataframe. BAP18_proteomics column inserted, but filled with NaN.
# E2F6 did not match any columns in proteomics dataframe. E2F6_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# BAP18 did not match any columns in proteomics dataframe. BAP18_proteomics column inserted, but filled with NaN.
# MGAM did not match any columns in proteomics dataframe. MGAM_proteomics column inserted, but filled with NaN.
# KDM6B did not match any columns in proteomics dataframe. KDM6B_proteomics column inserted, but filled with NaN.
# BAP18 did not match any columns in proteomics dataframe. BAP18_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['SENP3', 'TEX10', 'RUVBL1', 'LAS1L']
# Decreased in all cancers:
# []
# No change in all cancers:
# []
# Mixed results:
# ['TAF4', 'HSPA4', 'TAF6', 'HCFC1', 'WDR5', 'TAF7', 'TAF9', 'INO80C', 'PELP1', 'PRPF31', 'MCRS1', 'RNF2', 'KAT8', 'CHD8', 'ASH2L']
# Missing proteomics data in at least one cancer:
# ['MGAM', 'E2F6', 'TAF1', 'KMT2A', 'KDM6B', 'KANSL1', 'BAP18', 'PHF20']
#
#
# Emerin complex 32
#
# Borderline changes included; alpha set to 0.05
#
# RBL1 did not match any columns in proteomics dataframe. RBL1_proteomics column inserted, but filled with NaN.
#  did not match any columns in proteomics dataframe. _proteomics column inserted, but filled with NaN.
# TBL1Y did not match any columns in proteomics dataframe. TBL1Y_proteomics column inserted, but filled with NaN.
# BANF2 did not match any columns in proteomics dataframe. BANF2_proteomics column inserted, but filled with NaN.
#  did not match any columns in proteomics dataframe. _proteomics column inserted, but filled with NaN.
# TBL1Y did not match any columns in proteomics dataframe. TBL1Y_proteomics column inserted, but filled with NaN.
# BANF2 did not match any columns in proteomics dataframe. BANF2_proteomics column inserted, but filled with NaN.
# RBL1 did not match any columns in proteomics dataframe. RBL1_proteomics column inserted, but filled with NaN.
#  did not match any columns in proteomics dataframe. _proteomics column inserted, but filled with NaN.
# TBL1Y did not match any columns in proteomics dataframe. TBL1Y_proteomics column inserted, but filled with NaN.
# BANF2 did not match any columns in proteomics dataframe. BANF2_proteomics column inserted, but filled with NaN.
#  did not match any columns in proteomics dataframe. _proteomics column inserted, but filled with NaN.
# TBL1Y did not match any columns in proteomics dataframe. TBL1Y_proteomics column inserted, but filled with NaN.
# BANF2 did not match any columns in proteomics dataframe. BANF2_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['LMNB1', 'TRIM28', 'NMI', 'CHD4', 'RCOR1']
# Decreased in all cancers:
# ['SPTAN1']
# No change in all cancers:
# []
# Mixed results:
# ['SAP18', 'HDAC3', 'EMD', 'ACTB', 'HIST1H3A', 'RBL2', 'SMARCB1', 'HDAC1', 'SMARCC2', 'SMARCC1', 'TBL1XR1', 'DPY30', 'MED4']
# Missing proteomics data in at least one cancer:
# ['RBL1', '', 'TBL1Y', 'BANF2']
#
#
# Emerin complex 52
#
# Borderline changes included; alpha set to 0.05
#
# THRA did not match any columns in proteomics dataframe. THRA_proteomics column inserted, but filled with NaN.
# THRA did not match any columns in proteomics dataframe. THRA_proteomics column inserted, but filled with NaN.
# Increased in all cancers:
# ['DDX39A', 'LMNB1', 'HDGF', 'HNRNPU', 'NMI', 'API5']
# Decreased in all cancers:
# ['CKB']
# No change in all cancers:
# []
# Mixed results:
# ['LSM8', 'HNRNPL', 'YWHAQ', 'IQGAP1', 'EMD', 'ACTB', 'HNRNPK', 'YWHAE', 'SNRPD1', 'HIST1H1A', 'C1QBP', 'RBL2', 'ILF3', 'PDCD4', 'LEMD3']
# Missing proteomics data in at least one cancer:
# ['THRA']

# %%
pancancer_boxplot('Respiratory chain complex I (holoenzyme), mitochondrial')
# Out:
# Respiratory chain complex I (holoenzyme), mitochondrial
#
# Colon cancer:
# NDUFS8: 7.3287539294092275e-25
# NDUFA4: 0.04223417350533353
# NDUFAB1: 0.008800195812924025
# NDUFA1: 0.004372946089998221
# NDUFS4: 3.411602414126359e-34
# NDUFB5: 7.09567062380792e-13
# NDUFB3: 1.3735508491530879e-18
# NDUFB5: 5.6278984416925324e-70
# NDUFB3: 7.806226229991053e-79
# NDUFC1: 8.210892022736181e-70
# NDUFA2: 9.58824694543449e-82
# NDUFS5: 1.4152803274648173e-92
# NDUFS7: 1.1619725005694204e-83
# NDUFS2: 2.5366377755711934e-84
# NDUFS6: 2.4506610738623882e-92
# NDUFB1: 9.236714606807953e-63
# NDUFS3: 5.77232043385537e-83
# NDUFB6: 4.234288773208454e-62
# NDUFA3: 1.0188575806575846e-83
# NDUFB4: 4.429322876949035e-69
# NDUFB8: 4.495487560225989e-73
# NDUFB2: 2.4590311485402155e-51
# NDUFA7: 2.783378571468938e-92
# NDUFC2: 1.3551824973006928e-81
# NDUFA10: 7.0074771422121795e-96
# NDUFB10: 1.3397712204110983e-76
# MT-ND1: 3.974946177739079e-47
# MT-ND2: 4.115929993111271e-60
# MT-ND3: 2.6078944602789224e-11
# MT-ND5: 4.406324168124818e-52
# MT-ND6: 2.103487259583323e-15
# NDUFB7: 1.0748169628184593e-79
# NDUFV2: 8.601318752013871e-75
# NDUFS1: 1.243544270630662e-89
# NDUFV1: 1.7064050527010847e-94
# NDUFA8: 2.2940865533877976e-84
# NDUFV3: 1.964258675508639e-39
# NDUFA6: 4.780241350843878e-82
# NDUFA5: 2.926160827130156e-64
# NDUFA9: 2.1433996547398e-84
# NDUFA11: 4.919645377928191e-53
# NDUFB11: 3.7913797702001423e-63
# NDUFA13: 3.7658275947517284e-78
# NDUFA12: 4.744312410564155e-87
# NDUFB9: 1.1019445540656402e-82
#
#
# Ovarian cancer:
# NDUFS8: 0.3571182328625494
# NDUFA4: 0.6657283315524376
# NDUFAB1: 0.10215762709480669
# NDUFS4: 0.433704499282238
# NDUFB5: 0.02538369894596652
# NDUFB3: 0.0027153383108261624
# NDUFA2: 0.5399683422733593
# NDUFS5: 0.1011491658216363
# NDUFS7: 0.9442689175268237
# NDUFS2: 0.015851054368495505
# NDUFS6: 0.2758121850723144
# NDUFB1: 0.33228350212264457
# NDUFS3: 0.9687261776619431
# NDUFB6: 0.03648597379382351
# NDUFA3: 0.07847108864676254
# NDUFB4: 0.048534734155167535
# NDUFB8: 0.11023651384063647
# NDUFB2: 0.005870790716911772
# NDUFA7: 0.00033841612116952994
# NDUFC2: 0.12446518875660134
# NDUFA10: 0.3992755310277952
# NDUFB10: 0.3558634404580414
# MT-ND1: 0.9985737325982089
# MT-ND2: 0.03590784200869499
# MT-ND5: 0.003934337675474462
# NDUFB7: 0.6777501635607687
# NDUFV2: 0.12389941226734702
# NDUFS1: 0.01599561521959022
# NDUFV1: 0.36564782974020504
# NDUFA8: 0.6813233458266739
# NDUFV3: 4.9515351683971396e-05
# NDUFA6: 0.0009338503857826741
# NDUFA5: 0.1429081132392703
# NDUFA9: 0.2636209292964312
# NDUFA11: 0.8469093054708919
# NDUFB11: 0.9744520354600583
# NDUFA13: 0.8619829529329713
# NDUFA12: 0.04028303143045177
# NDUFB9: 0.3616228853938338

# %%
pancancer_plot_proteins('Condensin I complex')
